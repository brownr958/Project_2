# %%
import pandas as pd
import json
import pprint

# %%
baseball_df = pd.read_csv ('Cleaned_Data/all_data.csv')
baseball_df
baseball_df.to_json('Front_End/all_data.json')

# %%
baseball_json = baseball_df.to_json(orient="records")
# parsed = json.loads(baseball_json)
# json.dumps(parsed, indent=4)
baseball_json
# Out:
# '[{"AB":399,"AVG":0.353,"Age":26,"H":141,"HR":38,"Name":"Frank Thomas","OBP":0.487,"OPS":1.217,"Off":71.1,"Position":"1B","R":106,"RBI":101,"SB":2,"SLG":0.729,"Season":1994,"Team":"CHW","WAR":7.0,"playerid":255},{"AB":509,"AVG":0.299,"Age":34,"H":152,"HR":70,"Name":"Mark McGwire","OBP":0.47,"OPS":1.222,"Off":90.6,"Position":"1B","R":130,"RBI":147,"SB":1,"SLG":0.752,"Season":1998,"Team":"STL","WAR":8.5,"playerid":1008559},{"AB":423,"AVG":0.312,"Age":32,"H":132,"HR":52,"Name":"Mark McGwire","OBP":0.467,"OPS":1.198,"Off":68.4,"Position":"1B","R":104,"RBI":113,"SB":0,"SLG":0.73,"Season":1996,"Team":"OAK","WAR":7.3,"playerid":1008559},{"AB":400,"AVG":0.368,"Age":26,"H":147,"HR":39,"Name":"Jeff Bagwell","OBP":0.451,"OPS":1.201,"Off":66.3,"Position":"1B","R":104,"RBI":116,"SB":15,"SLG":0.75,"Season":1994,"Team":"HOU","WAR":7.8,"playerid":547},{"AB":580,"AVG":0.372,"Age":26,"H":216,"HR":42,"Name":"Todd Helton","OBP":0.463,"OPS":1.162,"Off":58.1,"Position":"1B","R":138,"RBI":147,"SB":5,"SLG":
# ...
